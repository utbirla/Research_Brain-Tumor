# %%
import tensorflow as tf
from zipfile import ZipFile
import os,glob
import cv2
from tqdm._tqdm_notebook import tqdm_notebook as tqdm
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Convolution2D, Dropout, Dense,MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Flatten
# Out:
# /var/folders/_6/yv4vw9w5033442shh7vwzfb40000gn/T/ipykernel_18790/2397208556.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook as tqdm

# %%
import os
import cv2
from tqdm import tqdm  # To show progress bar during the image loading process

# Paths to 'yes' and 'no' folders
yes_folder = "archive-2/brain_tumor_dataset/yes"
no_folder = "archive-2/brain_tumor_dataset/no"

# Initialize lists to store images and labels
X = []
y = []

# Function to load images from a given folder and label them
def load_images_from_folder(folder, label):
    for img_name in tqdm(os.listdir(folder)):
        img_path = os.path.join(folder, img_name)
        img = cv2.imread(img_path)
        if img is not None:  # Check if the image was loaded successfully
            img = cv2.resize(img, (224, 224))
            X.append(img)
            y.append(label)
        else:
            print(f"Warning: Could not load image {img_name}")

# Load images from 'yes' folder (Tumor present)
print("Loading images from 'yes' folder...")
load_images_from_folder(yes_folder, 'Y')

# Load images from 'no' folder (No tumor)
print("Loading images from 'no' folder...")
load_images_from_folder(no_folder, 'N')

# Check the length of images and labels
print(f"Number of images: {len(X)}")
print(f"Number of labels: {len(y)}")
# Out:
# Loading images from 'yes' folder...
# 100%|██████████| 155/155 [00:00<00:00, 1138.55it/s]
# Loading images from 'no' folder...
# 100%|██████████| 98/98 [00:00<00:00, 1097.99it/s]
# Number of images: 253
# Number of labels: 253

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for i in range(4):
    plt.subplot(1, 4, i+1)
    plt.imshow(X[i], cmap="gray")
    plt.axis('off')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print ("Shape of an image in X_train: ", X_train[0].shape)
print ("Shape of an image in X_test: ", X_test[0].shape)
# Out:
# Shape of an image in X_train:  (224, 224, 3)
# Shape of an image in X_test:  (224, 224, 3)

# %%
#preprocessing steps
le = preprocessing.LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=2)
y_train = np.array(y_train)
X_train = np.array(X_train)
y_test = np.array(y_test)
X_test = np.array(X_test)

# %%
print("X_train Shape: ", X_train.shape)
print("X_test Shape: ", X_test.shape)
print("y_train Shape: ", y_train.shape)
print("y_test Shape: ", y_test.shape)
# Out:
# X_train Shape:  (169, 224, 224, 3)
# X_test Shape:  (84, 224, 224, 3)
# y_train Shape:  (169, 2)
# y_test Shape:  (84, 2)

# %%
from tensorflow.keras.applications import ResNet50, VGG16, Xception
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

def load_pretrained_models(input_shape):
    resnet = ResNet50(include_top=False, weights='imagenet', input_shape=input_shape)
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=input_shape)
    xception = Xception(include_top=False, weights='imagenet', input_shape=input_shape)

    # Freeze the layers
    for model in [resnet, vgg16, xception]:
        for layer in model.layers:
            layer.trainable = False

    return resnet, vgg16, xception
from tensorflow.keras.layers import Dense

# Feature extraction and weighted averaging
def build_hybrid_model(input_shape, weights):
    inputs = Input(shape=input_shape)

    # Load pre-trained models without top classification layer
    resnet, vgg16, xception = load_pretrained_models(input_shape)

    # Global average pooling of features
    resnet_features = GlobalAveragePooling2D()(resnet(inputs))
    vgg16_features = GlobalAveragePooling2D()(vgg16(inputs))
    xception_features = GlobalAveragePooling2D()(xception(inputs))

    # Align feature dimensions using Dense layers (reduce to 512)
    resnet_features = Dense(512, activation='relu')(resnet_features)
    xception_features = Dense(512, activation='relu')(xception_features)

    # Weighted sum of features from different models
    hybrid_features = (weights[0] * resnet_features) + \
                      (weights[1] * vgg16_features) + \
                      (weights[2] * xception_features)

    # Final classification layer (for 2 classes: yes/no)
    hybrid_features_1 = Dense(4096,activation='relu')(hybrid_features)
    output = Dense(2, activation='softmax')(hybrid_features_1)

    model = Model(inputs=inputs, outputs=output)
    return model

    
# Train and evaluate the hybrid model on the brain tumor dataset
input_shape = (224, 224, 3)

# Define different weight ratios to experiment with
weight_ratios = [
    (0.33, 0.33, 0.33),  # Equal weights
    (0.5, 0.25, 0.25),   # ResNet dominance
    (0.25, 0.5, 0.25),   # VGG16 dominance
    (0.25, 0.25, 0.5)    # Xception dominance
]

# Best accuracy tracking
best_accuracy = 0
best_weights = None

# Loop through different weight ratios
for weights in weight_ratios:
    print(f"Training with weights: {weights}")
    model = build_hybrid_model(input_shape, weights)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=5, validation_data=(X_test, y_test), batch_size=32)

    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f"Accuracy with weights {weights}: {accuracy}")
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_weights = weights

print(f"Best weight ratio: {best_weights} with accuracy: {best_accuracy}")
# Out:
# Training with weights: (0.33, 0.33, 0.33)
# Epoch 1/5
# 6/6 [==============================] - 50s 9s/step - loss: 6.2632 - accuracy: 0.5976 - val_loss: 7.0188 - val_accuracy: 0.3929
# Epoch 2/5
# 6/6 [==============================] - 39s 7s/step - loss: 2.7791 - accuracy: 0.5680 - val_loss: 2.1739 - val_accuracy: 0.6071
# Epoch 3/5
# 6/6 [==============================] - 38s 7s/step - loss: 1.7126 - accuracy: 0.6509 - val_loss: 0.4067 - val_accuracy: 0.7976
# Epoch 4/5
# 6/6 [==============================] - 39s 7s/step - loss: 0.7265 - accuracy: 0.7101 - val_loss: 0.5609 - val_accuracy: 0.7738
# Epoch 5/5
# 6/6 [==============================] - 39s 7s/step - loss: 0.3396 - accuracy: 0.8639 - val_loss: 0.3060 - val_accuracy: 0.8810
# 3/3 [==============================] - 13s 4s/step - loss: 0.3060 - accuracy: 0.8810
# Accuracy with weights (0.33, 0.33, 0.33): 0.8809523582458496
# Training with weights: (0.5, 0.25, 0.25)
# Epoch 1/5
# 6/6 [==============================] - 41s 7s/step - loss: 5.1904 - accuracy: 0.6391 - val_loss: 0.4442 - val_accuracy: 0.8690
# Epoch 2/5
# 6/6 [==============================] - 39s 7s/step - loss: 2.5430 - accuracy: 0.6627 - val_loss: 0.3032 - val_accuracy: 0.8333
# Epoch 3/5
# 6/6 [==============================] - 45s 8s/step - loss: 1.1118 - accuracy: 0.6509 - val_loss: 0.2100 - val_accuracy: 0.9167
# Epoch 4/5
# 6/6 [==============================] - 51s 9s/step - loss: 0.5877 - accuracy: 0.7751 - val_loss: 0.2522 - val_accuracy: 0.8810
# Epoch 5/5
# 6/6 [==============================] - 52s 9s/step - loss: 0.3193 - accuracy: 0.8876 - val_loss: 0.3955 - val_accuracy: 0.7976
# 3/3 [==============================] - 16s 5s/step - loss: 0.3955 - accuracy: 0.7976
# Accuracy with weights (0.5, 0.25, 0.25): 0.7976190447807312
# Training with weights: (0.25, 0.5, 0.25)
# Epoch 1/5
# 6/6 [==============================] - 50s 9s/step - loss: 11.7469 - accuracy: 0.4260 - val_loss: 6.6642 - val_accuracy: 0.6071
# Epoch 2/5
# 6/6 [==============================] - 46s 8s/step - loss: 5.3064 - accuracy: 0.6154 - val_loss: 0.4235 - val_accuracy: 0.8214
# Epoch 3/5
# 6/6 [==============================] - 47s 8s/step - loss: 0.9647 - accuracy: 0.6864 - val_loss: 0.7837 - val_accuracy: 0.7619
# Epoch 4/5
# 6/6 [==============================] - 47s 8s/step - loss: 0.5311 - accuracy: 0.7929 - val_loss: 0.4626 - val_accuracy: 0.7976
# Epoch 5/5
# 6/6 [==============================] - 49s 9s/step - loss: 0.4432 - accuracy: 0.8225 - val_loss: 0.2977 - val_accuracy: 0.8452
# 3/3 [==============================] - 16s 5s/step - loss: 0.2977 - accuracy: 0.8452
# Accuracy with weights (0.25, 0.5, 0.25): 0.8452380895614624
# Training with weights: (0.25, 0.25, 0.5)
# Epoch 1/5
# 6/6 [==============================] - 50s 8s/step - loss: 10.9716 - accuracy: 0.5089 - val_loss: 3.7075 - val_accuracy: 0.6071
# Epoch 2/5
# 6/6 [==============================] - 46s 8s/step - loss: 2.3105 - accuracy: 0.6331 - val_loss: 0.7997 - val_accuracy: 0.6667
# Epoch 3/5
# 6/6 [==============================] - 48s 8s/step - loss: 0.6853 - accuracy: 0.6864 - val_loss: 0.3445 - val_accuracy: 0.8690
# Epoch 4/5
# 6/6 [==============================] - 48s 8s/step - loss: 0.4137 - accuracy: 0.8225 - val_loss: 0.2827 - val_accuracy: 0.9286
# Epoch 5/5
# 6/6 [==============================] - 47s 8s/step - loss: 0.3099 - accuracy: 0.8935 - val_loss: 0.2773 - val_accuracy: 0.8929
# 3/3 [==============================] - 15s 5s/step - loss: 0.2773 - accuracy: 0.8929
# Accuracy with weights (0.25, 0.25, 0.5): 0.8928571343421936
# Best weight ratio: (0.25, 0.25, 0.5) with accuracy: 0.8928571343421936
